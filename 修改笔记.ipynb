# %% [markdown]
# 首页轮播图说明
# 轮播图位于导航栏下方，展示了四张图片（周、魏晋、明、清），您可以根据实际资料替换或增减。
#
# 图片路径已使用您提供的文件名（1.周室-1.jpg 等），请确保这些图片与 index.html 在同一目录，或修改为正确路径。
#
# 轮播图支持手动左右箭头切换，底部圆点指示当前图片，并自动每隔5秒切换。
#
# 如需添加更多图片，只需在 <div class="carousel-slides"> 内复制一个 carousel-slide 并修改 style="background-image: url('图片路径');" 和说明文字即可。
